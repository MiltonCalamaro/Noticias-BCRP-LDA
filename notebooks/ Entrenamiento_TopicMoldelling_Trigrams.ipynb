# %%
# %matplotlib inline
import pickle
from pprint import pprint
import random
import warnings
import time
# numpy, pandas, matplotlib and regular expressions (data science essentials)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
# tqdm
from tqdm import tqdm
# spacy
import spacy
from spacy.lang.en import English
import en_core_web_sm
# gensim
import gensim
from gensim.models import LdaModel
from gensim import corpora
from gensim.models import CoherenceModel
# nltk
import nltk
from nltk.corpus import wordnet as wn
from nltk.corpus import words
from nltk.stem.wordnet import WordNetLemmatizer
# split
from sklearn.model_selection import train_test_split

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/Noticias_BCRP/notebooks")

# %%
df_noticias_bcrp=pd.read_pickle("../data/cleaned/df_noticias_bcrp_cleanedInfo_trigrams.pkl")
print(df_noticias_bcrp.shape)
df_noticias_bcrp.head()
# Out:
# (42275, 5)
#                                                Texto  ... Num_Words
# 0  dIZ207\n\n* FINANZAS.:.- -\n\nMomento de reest...  ...        78
# 1  ,\nx¿ºQ Denartamento de Prensa\n\nALUEVES Y1 D...  ...       190
# 2  TrO7\n\n \n\nECONOMISTA GONTÁLEZ IZQUIERDO\n\n...  ...        51
# 5  - 4 ENEL 2016 pégna 22\n\nFecha\n\nGESTIÓN\n\n...  ...       129
# 6  SiegoHarrero,geren-\ntedeinversionesde AFP\nHa...  ...       170
#
# [5 rows x 5 columns]

# %%
text_data=[i.split() for i in df_noticias_bcrp["Clean_Stopword_Info"]]
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]  
len(dictionary),len(corpus)
# Out:
# (33657, 42275)

# %%
pickle.dump( dictionary, open( "../models/topic_modelling/dictionary_trigrams.pkl", "wb" ) )
pickle.dump( corpus, open( "../models/topic_modelling/corpus_trigrams.pkl", "wb" ) )

# %%
print("Training LDA model on train dataframe...")
no_of_topics=[i for i in range(20,100,5)]
for i in no_of_topics:
  NUM_TOPICS = i
  start_time = time.time()
  ldamodel = LdaModel(corpus, 
                      num_topics=NUM_TOPICS, 
                      random_state=89, 
                      update_every=1,  
                      id2word=dictionary, 
                      passes=42, 
                      alpha='auto', 
                      per_word_topics=True)
  pickle.dump( ldamodel, open( "../models/topic_modelling/lda_models/model_trigrams_{}.pkl".format(NUM_TOPICS), "wb" ) )
# Out:
# Training LDA model on train dataframe...
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
list_coherence=[]
for i in no_of_topics:
  ldamodel=pickle.load(open( "../models/topic_modelling/lda_models/model_trigrams_{}.pkl".format(i), "rb" ))
  print("calculando coherencia topico {}".format(i))
  coherence_model_lda = CoherenceModel(model=ldamodel, texts=text_data, dictionary=dictionary, coherence='c_v')
  coherence_lda = coherence_model_lda.get_coherence()
  list_coherence.append(coherence_lda)
np.save( "../models/topic_modelling/list_coherence_bigrams.npy",list_coherence)
# Out:
# calculando coherencia topico 20
# calculando coherencia topico 25
# calculando coherencia topico 30
# calculando coherencia topico 35
# calculando coherencia topico 40
# calculando coherencia topico 45
# calculando coherencia topico 50
# calculando coherencia topico 55
# calculando coherencia topico 60
# calculando coherencia topico 65
# calculando coherencia topico 70
# calculando coherencia topico 75
# calculando coherencia topico 80
# calculando coherencia topico 85
# calculando coherencia topico 90
# calculando coherencia topico 95

# %%
data={"Number of Topics":no_of_topics,
 "Coherence Scores":list_coherence}
pd.DataFrame(data)
# Out:
#     Number of Topics  Coherence Scores
# 0                 20          0.545781
# 1                 25          0.522800
# 2                 30          0.520442
# 3                 35          0.532363
# 4                 40          0.535527
# 5                 45          0.532895
# 6                 50          0.545361
# 7                 55          0.537534
# 8                 60          0.525007
# 9                 65          0.516777
# 10                70          0.544863
# 11                75          0.518686
# 12                80          0.516827
# 13                85          0.502268
# 14                90          0.497028
# 15                95          0.499203

# %%
# Show graph
coherence_scores = list_coherence
plt.plot(no_of_topics, coherence_scores)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
### Se logra un mejor performance con 45 topicos
ldamodel=pickle.load(open("../models/topic_modelling/lda_models/model_trigrams_{}.pkl".format(50), "rb" ))

# %%
names_topic={0:"GOBIERNO PPK",1:"Encaje Monetario",2:"Temporada de Turismo",3:"Distrito Constructora",4:"PROYECTO GASODUCTO SUR",5:"PROYECTO CHINCHEROS",
                 6:"COMPETITIVIDAD ECONOMICA PERU",7:"VIVIENDA SOCIAL",8:"EMPLEO FORMAL", 9:"INVERSION PUBLICA",10:"PRECIOS DEL COMBUSTIBLE",
                 11:"DEFICIT FISCAL",12:"AGUA POTABLE",13:"LAVA JATO - ODEBRECHT",14:"PRECIOS AL CONSUMIDOR",15:"BOLSA DE VALORES LIMA",16:"PARTIDO NARANJA",
                 17:"COMERCIO EXTERIOR",18:"EMPRESAS COMERCIALES",19:"INVERSION PRIVADA",20:"SECTOR PESQUERO",21:"proceso judicial vizcarra",22:"FONDO DE PENSIONES",
                 23:"TARIFA ENERGIA ELECTRICA",24:"CIRCULACION MONEDA NACIONAL",25:"MERCADO CHINO Y USA",26:"PRODUCCION PETROLERA",27:"MEDIDAS DEL MEF",
                 28:"SALUD PUBLICA",29:"FENOMENO DEL NIÑO COSTERO",30:"EXPECTAVIDA DE INFLACION",31:"RECAUDACION TRIBUTARIA - SUNAT",
                 32:"BONOS FINANCIEROS DEL ESTADO",33:"CRECIMIENTO ECONOMICO",34:"PRODUCCION AGRICOLA - SECTORES",35:"MONEDAS ALUSIVAS",
                 36:"PRODUCCCION MINERA - COBRE",37:"TASA DE REFERENCIA",38:"PRODUCTOS DE EXPORTACION",39:"CREDITOS BANCARIOS",
                 40:"DIRECTORIO BCR - PRESIDENTE",41:"CRECIMIENTO PAISES LATINOAMERICANOS",42:"PROYECTO DE LEY - CONGRESO", 43:"TIPO DE CAMBIO - PRECIO DEL DOLAR",
                 44:"CRECIMIENTO ECONOMICO SOSTENIDO - PERU" }

# %%
topics = ldamodel.print_topics(num_topics=50,num_words=10)
for topic in topics:
    pprint(topic)
# Out:
# (0,
#  '0.066*"china" + 0.044*"unidos" + 0.037*"eeuu" + 0.026*"dijo" + '
#  '0.024*"europa" + 0.023*"trump" + 0.018*"mundial" + 0.018*"mundo" + '
#  '0.017*"crisis" + 0.017*"grecia"')
# (1,
#  '0.055*"directorio" + 0.034*"empresa" + 0.024*"contener" + 0.022*"desastres" '
#  '+ 0.019*"directores" + 0.013*"opinion_publica" + 0.013*"etiquetado" + '
#  '0.013*"digesa" + 0.011*"directivos" + 0.011*"gobierno_corporativo"')
# (2,
#  '0.025*"monto_negociado" + 0.021*"fujimori" + 0.020*"adenda" + '
#  '0.020*"vizcarra" + 0.020*"fuerza_popular" + 0.019*"fujimorismo" + '
#  '0.016*"ppk" + 0.015*"oposicion" + 0.015*"popular" + 0.015*"martin_vizcarra"')
# (3,
#  '0.067*"precio" + 0.062*"precios" + 0.025*"niño" + 0.020*"alimentos" + '
#  '0.020*"lluvias" + 0.017*"produccion" + 0.014*"productores" + '
#  '0.014*"fenomeno_niño" + 0.013*"mercado" + 0.013*"promedio"')
# (4,
#  '0.025*"jato" + 0.022*"toledo" + 0.021*"caso" + 0.020*"investigacion" + '
#  '0.016*"garcia" + 0.014*"brasil" + 0.013*"lava_jato" + 0.012*"humala" + '
#  '0.012*"fiscal" + 0.011*"presidente"')
# (5,
#  '0.078*"congreso" + 0.036*"ejecutivo" + 0.030*"ley" + 0.020*"dijo" + '
#  '0.016*"propuesta" + 0.016*"proyecto" + 0.015*"proyecto_ley" + '
#  '0.014*"comision" + 0.012*"indico" + 0.011*"debate"')
# (6,
#  '0.090*"pago_impuestos" + 0.046*"inversores_extranjeros" + '
#  '0.025*"certificados_deposito" + 0.022*"mercado_capitales" + 0.021*"enjulio" '
#  '+ 0.020*"banco_central" + 0.015*"tasa_interanual" + 0.013*"riesgo_pais" + '
#  '0.013*"smv" + 0.013*"plazo"')
# (7,
#  '0.040*"viviendas" + 0.038*"vivienda" + 0.018*"precios" + 0.018*"lima" + '
#  '0.013*"casas" + 0.012*"año" + 0.012*"distritos" + 0.011*"mil" + '
#  '0.011*"construccion" + 0.011*"fondo_mivivienda"')
# (8,
#  '0.088*"unidades_dolar" + 0.030*"personas" + 0.026*"empleo" + 0.025*"años" + '
#  '0.021*"poblacion" + 0.019*"promedio" + 0.017*"pobreza" + 0.017*"peruanos" + '
#  '0.016*"educacion" + 0.015*"ingresos"')
# (9,
#  '0.064*"agua" + 0.021*"sedapal" + 0.020*"emergencia" + 0.018*"servicio" + '
#  '0.018*"eps" + 0.014*"unidades_frente" + 0.011*"agua_potable" + '
#  '0.010*"gestion" + 0.010*"sunass" + 0.010*"saneamiento"')
# (10,
#  '0.059*"proyectos" + 0.052*"millones_soles" + 0.040*"inversion" + '
#  '0.038*"presupuesto" + 0.036*"gobierno" + 0.023*"inversion_publica" + '
#  '0.019*"ejecucion" + 0.017*"nacional" + 0.017*"infraestructura" + '
#  '0.016*"publica"')
# (11,
#  '0.110*"mef" + 0.054*"ministro_economia" + 0.047*"gobierno" + 0.041*"zavala" '
#  '+ 0.034*"dijo" + 0.028*"afirmo" + 0.023*"alfredo_thorne" + 0.015*"aseguro" + '
#  '0.015*"cooper" + 0.014*"segura"')
# (12,
#  '0.072*"afp" + 0.034*"pensiones" + 0.030*"fondo" + 0.021*"afiliados" + '
#  '0.020*"pension" + 0.020*"sistema" + 0.017*"años" + 0.016*"fondos" + '
#  '0.016*"sbs" + 0.013*"comision"')
# (13,
#  '0.044*"presidente" + 0.035*"ppk" + 0.032*"gobierno" + 0.030*"corrupcion" + '
#  '0.026*"kuczynski" + 0.018*"politica" + 0.015*"confianza" + 0.014*"ministros" '
#  '+ 0.014*"politico" + 0.014*"mandatario"')
# (14,
#  '0.111*"puntos" + 0.077*"reconstruccion" + 0.030*"expectativas" + '
#  '0.027*"encuesta" + 0.025*"nivel" + 0.023*"meses" + 0.022*"empresas" + '
#  '0.022*"percepcion" + 0.018*"expectativa" + 0.018*"situacion"')
# (15,
#  '0.041*"cobre" + 0.034*"mineria" + 0.032*"produccion" + 0.026*"proyectos" + '
#  '0.023*"minera" + 0.017*"proyecto" + 0.015*"mineros" + 0.015*"inversion" + '
#  '0.014*"oro" + 0.014*"inversiones"')
# (16,
#  '0.061*"contraloria" + 0.046*"chinchero" + 0.024*"ositran" + '
#  '0.020*"kuntur_wasi" + 0.019*"aeropuerto" + 0.019*"decreto" + 0.016*"cuota" + '
#  '0.014*"cusco" + 0.013*"decreto_legislativo" + 0.012*"informe"')
# (17,
#  '0.029*"solo" + 0.024*"gobierno" + 0.020*"pais" + 0.020*"años" + '
#  '0.018*"ahora" + 0.016*"sino" + 0.016*"pues" + 0.014*"hoy" + 0.014*"bien" + '
#  '0.013*"menos"')
# (18,
#  '0.050*"empresas" + 0.017*"procesos" + 0.015*"informacion" + 0.015*"gestion" '
#  '+ 0.012*"proceso" + 0.012*"sistema" + 0.011*"empresa" + 0.010*"regulacion" + '
#  '0.010*"reglamento" + 0.010*"control"')
# (19,
#  '0.125*"ciento" + 0.034*"bancada" + 0.028*"manufactura_primaria" + '
#  '0.022*"limon" + 0.019*"horas" + 0.015*"nuevo_esquema" + 0.015*"ago" + '
#  '0.014*"cas" + 0.013*"captura" + 0.012*"quijandria"')
# (20,
#  '0.050*"lima" + 0.032*"piura" + 0.028*"regiones" + 0.020*"norte" + '
#  '0.019*"libertad" + 0.019*"pais" + 0.017*"arequipa" + 0.016*"region" + '
#  '0.015*"ciudades" + 0.013*"operador"')
# (21,
#  '0.223*"peru" + 0.076*"pais" + 0.025*"paises" + 0.019*"peruano" + '
#  '0.018*"region" + 0.018*"desarrollo" + 0.016*"chile" + 0.014*"mundo" + '
#  '0.013*"america_latina" + 0.010*"internacional"')
# (22,
#  '0.057*"banco_central" + 0.045*"dolar" + 0.043*"tipo_cambio" + 0.036*"bcr" + '
#  '0.028*"inflacion" + 0.025*"bancos" + 0.020*"moneda_local" + 0.017*"mercado" '
#  '+ 0.015*"autoridad_monetaria" + 0.013*"año"')
# (23,
#  '0.069*"crecimiento" + 0.062*"año" + 0.038*"economia" + 0.019*"pbi" + '
#  '0.017*"inversion" + 0.016*"inversion_privada" + 0.015*"economia_peruana" + '
#  '0.013*"recuperacion" + 0.013*"espera" + 0.013*"inversion_publica"')
# (24,
#  '0.050*"petroperu" + 0.034*"thorne" + 0.022*"petroleo" + 0.021*"lote" + '
#  '0.017*"perupetro" + 0.017*"talara" + 0.014*"combustibles" + 0.014*"precios" '
#  '+ 0.013*"refineria_talara" + 0.012*"hidrocarburos"')
# (25,
#  '0.035*"productividad" + 0.017*"deficit_comercial" + 0.015*"mano_obra" + '
#  '0.012*"complejo" + 0.012*"modelo" + 0.010*"diversificacion" + '
#  '0.010*"despido" + 0.010*"diagnostico" + 0.009*"diversificacion_productiva" + '
#  '0.008*"sector_manufactura"')
# (26,
#  '0.027*"mercado" + 0.024*"acciones" + 0.023*"inversion" + '
#  '0.021*"inversionistas" + 0.020*"bonos" + 0.017*"fondos" + 0.017*"empresas" + '
#  '0.014*"inversiones" + 0.013*"activos" + 0.012*"rentabilidad"')
# (27,
#  '0.057*"ventas" + 0.034*"empresas" + 0.024*"venta" + 0.022*"negocios" + '
#  '0.019*"mercado" + 0.019*"compra" + 0.018*"comercio" + 0.018*"productos" + '
#  '0.016*"compras" + 0.016*"consumo"')
# (28,
#  '0.019*"billetes" + 0.017*"liquidez_dolares" + 0.016*"policia" + '
#  '0.016*"depositos_plazo" + 0.014*"aeropuerto_chinchero" + 0.014*"delito" + '
#  '0.013*"nsnc" + 0.012*"mil" + 0.012*"circulante" + 0.011*"tres"')
# (29,
#  '0.027*"acuerdo" + 0.023*"reino_unido" + 0.021*"crisis_politica" + '
#  '0.020*"negociaciones" + 0.017*"australia" + 0.016*"sep" + 0.016*"tpp" + '
#  '0.011*"brexit" + 0.011*"historico" + 0.011*"union_europea"')
# (30,
#  '0.034*"fiscalia" + 0.019*"dinero" + 0.019*"informacion" + 0.017*"prevencion" '
#  '+ 0.016*"investigaciones" + 0.014*"activos" + 0.011*"lavado_activos" + '
#  '0.011*"abogado" + 0.010*"declaraciones" + 0.010*"sanchez"')
# (31,
#  '0.062*"mercado" + 0.035*"consumidores" + 0.034*"indecopi" + '
#  '0.029*"consumidor" + 0.024*"competencia" + 0.019*"empresas" + 0.016*"marca" '
#  '+ 0.016*"precios" + 0.015*"producto" + 0.013*"caso"')
# (32,
#  '0.057*"año" + 0.045*"mes" + 0.033*"aumento" + 0.032*"meses" + 0.031*"mayo" + '
#  '0.028*"julio" + 0.028*"junio" + 0.027*"abril" + 0.027*"bcr" + 0.027*"marzo"')
# (33,
#  '0.034*"salud" + 0.021*"plataforma" + 0.020*"sni" + 0.018*"canal" + '
#  '0.018*"comercio" + 0.015*"aljovin" + 0.015*"dejulio" + 0.014*"tlc" + '
#  '0.010*"transito" + 0.009*"medicamentos"')
# (34,
#  '0.019*"caso" + 0.017*"promedio_diario" + 0.016*"encaje" + '
#  '0.016*"tasa_encaje" + 0.015*"obligaciones" + 0.013*"banco_central" + '
#  '0.013*"plazo" + 0.012*"pago" + 0.012*"articulo" + 0.010*"monto"')
# (35,
#  '0.049*"exportaciones" + 0.033*"productos" + 0.016*"exportacion" + '
#  '0.016*"envios" + 0.015*"producto" + 0.014*"produccion" + '
#  '0.014*"exportaciones_tradicionales" + 0.014*"tradicionales" + '
#  '0.014*"importaciones" + 0.014*"sector"')
# (36,
#  '0.056*"credito" + 0.041*"creditos" + 0.038*"bancos" + 0.024*"prestamos" + '
#  '0.024*"empresas" + 0.022*"financiamiento" + 0.017*"banca" + '
#  '0.017*"tasas_interes" + 0.016*"sistema_financiero" + '
#  '0.012*"entidades_financieras"')
# (37,
#  '0.080*"zona_euro" + 0.032*"tasa_promedio" + 0.031*"ccl" + '
#  '0.031*"camara_comercio" + 0.029*"director_ejecutivo" + 0.020*"mejoro" + '
#  '0.019*"var" + 0.017*"castro" + 0.017*"ejecutivos" + 0.017*"viajes"')
# (38,
#  '0.060*"trabajadores" + 0.035*"trabajo" + 0.029*"laboral" + '
#  '0.018*"inversores_institucionales" + 0.016*"empresas" + 0.015*"cts" + '
#  '0.015*"empleo" + 0.014*"trabajador" + 0.011*"informalidad" + 0.011*"essalud"')
# (39,
#  '0.208*"soles" + 0.165*"dolares" + 0.074*"moneda_peruana" + 0.041*"empresas" '
#  '+ 0.037*"sol" + 0.031*"viernes" + 0.030*"banco_central" + 0.029*"moneda" + '
#  '0.019*"año" + 0.015*"monedas"')
# (40,
#  '0.486*"millones" + 0.166*"millones_dolares" + 0.042*"año" + 0.039*"monto" + '
#  '0.024*"total" + 0.020*"dolares" + 0.018*"reservas_internacionales" + '
#  '0.013*"periodo" + 0.007*"usd_millones" + 0.005*"inundaciones"')
# (41,
#  '0.045*"produce" + 0.039*"pesca" + 0.035*"mercado_informal" + '
#  '0.026*"industria" + 0.021*"giuffra" + 0.020*"anchoveta" + '
#  '0.017*"reduccion_tasa" + 0.017*"sector" + 0.016*"ministerio_produccion" + '
#  '0.014*"bruno_giuffra"')
# (42,
#  '0.084*"bcrp" + 0.063*"moneda_nacional" + 0.052*"moneda_extranjera" + '
#  '0.039*"extranjera" + 0.029*"circular_bcrp" + 0.029*"banco_central" + '
#  '0.025*"tasa_interes" + 0.022*"plazo" + 0.020*"promedio" + '
#  '0.019*"sistema_financiero"')
# (43,
#  '0.054*"julio_velarde" + 0.054*"pbi" + 0.049*"velarde" + 0.049*"fiscal" + '
#  '0.034*"deficit" + 0.031*"gasto" + 0.029*"sector_publico" + '
#  '0.026*"presidente_bcr" + 0.025*"deficit_fiscal" + 0.024*"bcr"')
# (44,
#  '0.056*"sunat" + 0.032*"recaudacion" + 0.024*"igv" + 0.024*"empresas" + '
#  '0.019*"renta" + 0.019*"impuestos" + 0.018*"contribuyentes" + '
#  '0.018*"tributaria" + 0.016*"impuesto_renta" + 0.016*"impuesto"')
# (45,
#  '0.024*"clientes" + 0.021*"operaciones" + 0.019*"pagos" + 0.018*"ahorro" + '
#  '0.017*"pago" + 0.013*"personas" + 0.012*"cuenta" + 0.012*"sbs" + '
#  '0.012*"dinero" + 0.012*"transacciones"')
# (46,
#  '0.030*"turismo" + 0.017*"comercio_exterior" + 0.014*"evento" + 0.012*"lima" '
#  '+ 0.011*"mincetur" + 0.011*"comercio" + 0.011*"servicios" + 0.010*"ministro" '
#  '+ 0.010*"reuniones" + 0.009*"desastres_naturales"')
# (47,
#  '0.037*"energia" + 0.035*"gas" + 0.022*"gas_natural" + 0.013*"electricidad" + '
#  '0.013*"osinergmin" + 0.013*"abril_mayo" + 0.012*"generacion" + '
#  '0.011*"demanda" + 0.011*"precio" + 0.011*"mem"')
# (48,
#  '0.072*"proyecto" + 0.025*"construccion" + 0.022*"obras" + 0.017*"lima" + '
#  '0.015*"mtc" + 0.012*"obra" + 0.011*"linea" + 0.011*"gestion" + '
#  '0.010*"linea_metro" + 0.009*"alarcon"')
# (49,
#  '0.075*"odebrecht" + 0.035*"contrato" + 0.033*"proyecto" + 0.029*"empresa" + '
#  '0.016*"concesion" + 0.016*"consorcio" + 0.013*"gasoducto_sur" + '
#  '0.013*"ministerio_publico" + 0.012*"peruano" + 0.012*"gsp"')
